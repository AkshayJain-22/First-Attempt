# %% [raw]
# Q1. What is the relationship between classes and modules?
# Ans. Both classes and modules have their own attributes. In case of classes attributes can be used by creating an instance,          similarly by imporing a module, it's attributes can be used. Also, they have similarities in the way their attributes are        used.
#      class_object.attribute_name()
#      module_name.attribute_name()
#
# Q2. How do you make instances and classes?
# Ans. classes are made using the key word 'class'
#      eg. class class_name:
#              pass
#      Instances are made using the class name of which it is being made.
#      eg. instance_name = class_name()
#
# Q3. Where and how should be class attributes created?
# Ans. Class attributes are created inside a class body but outside any function of the class.
#      class class_name():
#          attribute1 = 1
#          attribute2 = 2
#          #outside any function
#          def__init__():
#              pass
#
#
# Q4. Where and how are instance attributes created?
# Ans. Instance attributes are created inside the __init__() function of the the class. It is called automatically when an intance      is created.
#      class class_name():
#          def__init__(self,a,b,c):
#              self.inst1 = a
#              self.inst2 = b
#              self.inst3 = c
#
#
# Q5. What does the term "self" in a Python class mean?
#
# Ans. Term 'self' refers to a pointer that points to the instance for which a particular function of the class is called. Without      this pointer compiler can not understand that values of which instance to be used.
#
# Q6. How does a Python class handle operator overloading?
# Ans. Every operator has an associated function with it which is invoked whenever that operator is used. We can write define our      own behaviour for every operator but cannot create a new operator.
#      eg. class A:
#             def __init__(self, a):
#                 self.a = a
#
#             # adding two objects
#             def __add__(self, o):
#                 return self.a + o.a
#         ob1 = A(1)
#         ob2 = A(2)
#         ob3 = A("Geeks")
#         ob4 = A("For")
#
#         print(ob1 + ob2)
#         print(ob3 + ob4)
#
#         Output : 3
#                  GeeksFor
#
#
# Q7. When do you consider allowing operator overloading of your classes?
# Ans. When we create our own class with our own behaviours it creates a data type for which the compiler does not know how to use      an operator. In such cases, we need to overload the operator with newly defined functionality.
#
# Q8. What is the most popular form of operator overloading?
# Ans. The add operator : '+'
#      If the operands are numbers it adds them : 1+3 = 4
#      But if operands are char/strings, it concatenates them : '1'+'3'='13'
#
#
# Q9. What are the two most important concepts to grasp in order to comprehend Python OOP code?
# Ans.Inheritance and Polymorphism.
