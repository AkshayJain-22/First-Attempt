# %% [raw]
# 1. What exactly is []?
# Ans. This is used to define a list. Values seperated by commas(,) between these braces are assigned to a list as one element        each. If no elements are present it makes an empty list.
#      eg. l=[] is an empty list
#          l=[1,2,3,4] contains four elements.
#
# 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)
# Ans. spam[2] = 'hello'
#
# Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
#
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
# Ans. 'd'
#
# 4. What is the value of spam[-1]?
# Ans. 'd'
#
# 5. What is the value of spam[:2]?
# Ans. 'a','b'
#
# Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat', True] for the next three questions.
#
# 6. What is the value of bacon.index('cat')?
# Ans. 1
#
# 7. How does bacon.append(99) change the look of the list value in bacon?
# Ans. It will add another element to the list at the end with the value 99.
#      [3.14, 'cat,' 11, 'cat', True, 99]
#
# 8. How does bacon.remove('cat') change the look of the list in bacon?
# Ans. It will remove the first occurence of 'cat' from bacon
#      [3.14, 11, 'cat', True, 99]
#
# 9. What are the list concatenation and list replication operators?
# Ans. list concatenation: +
#      list replication: *
#
# 10. What is difference between the list methods append() and insert()?
# Ans. append() adds any element at the end of the list.
#      insert() adds the element at any desired place in a list.
#
# 11. What are the two methods for removing items from a list?
# Ans.i) pop()
#     ii)remove()
#
# 12. Describe how list values and string values are identical.
# Ans. A list is defined as an array of values stored under a common name. String is also a list but, all elements are of              'str' data type. Similar to lists, a srtring is an iterable object. Many functions of string class are similar to that of      lists.
#
# 13. What's the difference between tuples and lists?
# Ans. Tuples are immutable objects whereas lists are mutable. Tuples ensure a higher data security as compared to lists.
#      Additionally, Tuples enclose the values between '()' whereas, lists enclose the values between '[]'
#
# 14. How do you type a tuple value that only contains the integer 42?
# Ans. tuple_name = (42,)
#
# 15. How do you get a list value's tuple form? How do you get a tuple value's list form?
# Ans. i) By type casting to tuple: print(tuple(list_name))
#      ii)By type casting to list : print(list(tuple_name))
#
# 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
# Ans. A tuple is not a list but can contain list values as its tuple values.
#
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?
# Ans. copy() creates a shallow copy of the object 'copy'. Any changes made to the 'copy' object will also be reflected in its        child object where it is copied. Its like creating an alias which are using same values as reference.
#      copy.deepcopy() creates a deep copy of the object 'copy'. Any changes made to this object will not be reflected in its          child object where it is copied.Here a completely new object is made with the values of 'copy' which can be changed            independently.
