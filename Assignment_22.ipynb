# %% [raw]
# 1. What is the result of the code, and explain?
#
# >>> X = 'iNeuron'
# >>> def func():
#         print(X)
#
#
# >>> func()
# Output: iNeuron
#
# Explaination: We are calling a function named 'func()'. This func() function uses a print statement to ouput the result of a variable 'X' whose scope is available to func() therefore it is printing its value i.e. 'iNeuron'.
#
# 2. What is the result of the code, and explain?
#
#
# >>> X = 'iNeuron'
# >>> def func():
#         X = 'NI!'
#
#
# >>> func()
# >>> print(X)
# Ouput: iNeuron
#
# Explaination: There are two Xs in the code. One lies outside the function func() which is called global X here. Other one is inside func() whose scope ends withing the function func(). So, when we print X outside the func() we access the global X hence we obtain 'iNeuron' as output.
#
# 3. What does this code print, and why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI'
# print(X)
#
#
# >>> func()
# >>> print(X)
#
# Output: NI
#         iNeuron
#
# Explaination: Again, we have two Xs. One is global one which has the value 'iNeuron' and other one inside function func() whose scope is confined to func(). When we call func(), it prints the X which is defined inside it. On the other hand when we print X outside func() it prints the one with global scope.
#
# 4. What output does this code produce? Why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# global X
# X = 'NI'
#
#
# >>> func()
# >>> print(X)
#
# Output: 'NI'
#
# Explaination: The keyword global is used to access a variable with global scope. So inside the function func(), we have accessed global variable X and changed it's value from 'iNeuron' to 'NI'. Therefore when we print X we obtain 'NI'.
#
# 5. What about this code—what’s the output, and why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI'
# def nested():
# print(X)
# nested()
#
#
# >>> func()
# >>> X
#
# Output: NI
#        'iNeuron'
#
# Explaination: We have a function 'nested()' which is nested inside another function 'func()'. Also we have two Xs, one is inside func() and other one is global (outside any function). So when the 'nested()' prints the value of X it is accessing the one inside 'func()'. Whereas, when we access X outside any function we are pointing at the global one. Accordingly, thier respective values are printed.
#
# 6. How about this code: what is its output in Python 3, and explain?
#
#
# >>> def func():
# X = 'NI'
# def nested():
# nonlocal X
# X = 'Spam'
# nested()
# print(X)
#
#
# >>> func()
# Output: Spam
# Explaination: We have a function 'nested()' which is nested inside another function 'func()'. nonlocal keyword is used in the case of nested functions. This keyword works similar to the global, but rather than global, this keyword declares a variable to point to the variable of outside enclosing function, in case of nested functions.
# So, inside nested() it uses 'nonlocal' which changes the value of X (which was declared in func()) from 'NI' to 'Spam'. Therefore, Spam is printed in the output.
